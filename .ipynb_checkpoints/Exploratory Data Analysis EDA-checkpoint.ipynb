# %%
import pandas as pd
import os   # change directory

# %%
os.chdir('/Users/Nurullainy/git_Lainy/Data-Mining - Lab Exercise')

# %%
df = pd.read_csv('lab1.csv')

# %%
df.head(10)
# Out:
#    TargetB      ID  GiftCnt36  GiftCntAll  GiftCntCard36  GiftCntCardAll  \
# 0        0   14974          2           4              1               3
# 1        0    6294          1           8              0               3
# 2        1   46110          6          41              3              20
# 3        1  185937          3          12              3               8
# 4        0   29637          1           1              1               1
# 5        1  112632          3          11              2               9
# 6        0  123712          2           4              2               3
# 7        0   45409          1           4              0               3
# 8        1   19094          1           3              0               1
# 9        0  178271          1           5              1               2
#
#    GiftAvgLast  GiftAvg36  GiftAvgAll  GiftAvgCard36  ...  PromCntCardAll  \
# 0         17.0      13.50        9.25          17.00  ...              13
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9686 entries, 0 to 9685
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   TargetB           9686 non-null   int64
#  1   ID                9686 non-null   category
#  2   GiftCnt36         9686 non-null   int64
#  3   GiftCntAll        9686 non-null   int64
#  4   GiftCntCard36     9686 non-null   int64
#  5   GiftCntCardAll    9686 non-null   int64
#  6   GiftAvgLast       9686 non-null   float64
#  7   GiftAvg36         9686 non-null   float64
#  8   GiftAvgAll        9686 non-null   float64
#  9   GiftAvgCard36     7906 non-null   float64
#  10  GiftTimeLast      9686 non-null   int64
#  11  GiftTimeFirst     9686 non-null   int64
#  12  PromCnt12         9686 non-null   int64
#  13  PromCnt36         9686 non-null   int64
#  14  PromCntAll        9686 non-null   int64
#  15  PromCntCard12     9686 non-null   int64
# ...

# %%
# Number of rows and fields

df.shape
# Out:
# (9686, 28)

# %%
df.describe()
# Out:
#            TargetB             ID      TargetD    GiftCnt36   GiftCntAll  \
# count  9686.000000    9686.000000  4843.000000  9686.000000  9686.000000
# mean      0.500000   97975.474086    15.624344     3.205451    10.507640
# std       0.500026   56550.171120    12.445137     2.133421     8.993401
# min       0.000000      12.000000     1.000000     0.000000     1.000000
# 25%       0.000000   48835.500000    10.000000     2.000000     4.000000
# 50%       0.500000   99106.000000    13.000000     3.000000     8.000000
# 75%       1.000000  148538.750000    20.000000     4.000000    15.000000
# max       1.000000  191779.000000   200.000000    16.000000    91.000000
#
#        GiftCntCard36  GiftCntCardAll  GiftAvgLast    GiftAvg36   GiftAvgAll  \
# count    9686.000000     9686.000000  9686.000000  9686.000000  9686.000000
# mean        1.856597        5.582490    16.017739    14.876203    12.489325
# std         1.595419        4.736894    12.041805    10.057007     9.209297
# ...

# %%
dem_age = df['DemAge']
dem_age.head(10)
# Out:
# 0     NaN
# 1    67.0
# 2     NaN
# 3     NaN
# 4    53.0
# 5    47.0
# 6    58.0
# 7     NaN
# 8     NaN
# 9     NaN
# Name: DemAge, dtype: float64

# %%
dem_age.count()
# Out:
# 7279

# %%
dem_age.unique()
# Out:
# array([nan, 67., 53., 47., 58., 39., 50., 45., 80., 61., 76., 41., 75.,
#        59., 51., 31., 54., 70., 42., 65., 81., 38., 56., 69., 52., 33.,
#        73., 71., 29., 60., 83., 43., 35., 77., 44., 72., 64., 34., 55.,
#        37., 57., 46., 49., 32., 66., 87., 40., 79., 25., 63., 62., 48.,
#        68., 86., 23., 27., 74., 78., 85., 26.,  7., 36., 82., 24., 17.,
#        30., 84., 21., 28., 22., 19., 16., 14.,  6.,  0.,  2., 20., 18.,
#        15.,  4.])

# %%
dem_age.value_counts()
# Out:
# 73.0    216
# 67.0    215
# 75.0    203
# 49.0    201
# 57.0    187
#        ...
# 2.0       1
# 20.0      1
# 4.0       1
# 18.0      1
# 15.0      1
# Name: DemAge, Length: 79, dtype: int64

# %%
df.groupby('DemAge').mean()
# Out:
#          TargetB             ID    TargetD  GiftCnt36  GiftCntAll  \
# DemAge
# 0.0     0.000000   89765.000000        NaN   4.000000    8.000000
# 2.0     0.000000  148098.000000        NaN   1.000000    4.000000
# 4.0     1.000000  179339.000000  13.000000   6.000000   10.000000
# 6.0     0.333333   59613.666667  14.000000   2.666667   16.333333
# 7.0     0.343750   79246.156250  13.272727   3.812500   15.937500
# ...          ...            ...        ...        ...         ...
# 83.0    0.469565   76073.373913  15.564815   3.339130   14.634783
# 84.0    0.457143   95185.342857  13.937500   3.442857   15.300000
# 85.0    0.386667   88468.306667  15.482759   3.360000   15.640000
# 86.0    0.500000   87064.661765  11.529412   3.602941   15.897059
# 87.0    0.445946   98005.797297  12.636364   3.445946   14.743243
#
#         GiftCntCard36  GiftCntCardAll  GiftAvgLast  GiftAvg36  GiftAvgAll  \
# DemAge
# 0.0          3.000000        4.000000    14.000000  14.000000   11.000000
# ...

# %%
df.groupby('TargetB').mean()
# Out:
#                    ID    TargetD  GiftCnt36  GiftCntAll  GiftCntCard36  \
# TargetB
# 0        97025.279166        NaN   2.911419    9.530456       1.646913
# 1        98925.669007  15.624344   3.499484   11.484823       2.066281
#
#          GiftCntCardAll  GiftAvgLast  GiftAvg36  GiftAvgAll  GiftAvgCard36  \
# TargetB
# 0              5.049143    16.866519  15.701922   13.141708      15.126377
# 1              6.115837    15.168959  14.050483   11.836942      13.391815
#
#          ...  PromCntAll  PromCntCard12  PromCntCard36  PromCntCardAll  \
# TargetB  ...
# 0        ...   46.699566       5.331613      11.506711       18.373942
# 1        ...   50.267396       5.452406      12.402643       19.640306
#
#          StatusCatStarAll  DemCluster     DemAge  DemMedHomeValue  \
# TargetB
# 0                0.485443   27.591988  58.304444    105602.457155
# 1                0.595705   26.708652  59.979070    116370.142474
#
#          DemPctVeterans  DemMedIncome
# TargetB
# ...

# %%
df.groupby(['TargetB', 'DemGender']).count()
# Out:
#                      ID  TargetD  GiftCnt36  GiftCntAll  GiftCntCard36  \
# TargetB DemGender
# 0       F          2614        0       2614        2614           2614
#         M          1963        0       1963        1963           1963
#         U           266        0        266         266            266
# 1       F          2609     2609       2609        2609           2609
#         M          1962     1962       1962        1962           1962
#         U           272      272        272         272            272
#
#                    GiftCntCardAll  GiftAvgLast  GiftAvg36  GiftAvgAll  \
# TargetB DemGender
# 0       F                    2614         2614       2614        2614
#         M                    1963         1963       1963        1963
#         U                     266          266        266         266
# 1       F                    2609         2609       2609        2609
#         M                    1962         1962       1962        1962
# ...

# %%
# Normalize the data attributes for the dataset
from sklearn import preprocessing
import numpy as np


# separate the data from the target attributes
x_array = np.array(df['ID'])
y = df['TargetB']

# normalize the data attributes
normalized_X = preprocessing.normalize([x_array])

# %%
normalized_X
# Out:
# array([[0.00134498, 0.00056533, 0.00414164, ..., 0.01661453, 0.01661632,
#         0.00017317]])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

dem_age = dem_age.dropna()
sns.distplot(dem_age)

# %%
sns.countplot(dem_age)

# %%
df['DemHomeOwner']=df['DemHomeOwner'].replace({'H': 1,'U':0})

# %%
fig, ax = plt.subplots(figsize=(10,8))
plt.suptitle('')
df.boxplot(column=['TargetB'], by='DemHomeOwner', ax=ax)

# %%
dem_cluster = df['DemCluster'].dropna()
sns.countplot(dem_cluster)

# %%
dem_cluster = df['DemCluster'].dropna()
sns.distplot(dem_cluster)

# %%
fig, ax = plt.subplots(figsize=(10,8))
plt.suptitle('')
df.boxplot(column=['DemCluster'])

# %%
x = pd.Series.value_counts(df.DemAge, bins=10)
x
# Out:
# (69.6, 78.3]     1437
# (60.9, 69.6]     1250
# (43.5, 52.2]     1223
# (52.2, 60.9]     1043
# (78.3, 87.0]      932
# (34.8, 43.5]      889
# (26.1, 34.8]      342
# (17.4, 26.1]       72
# (8.7, 17.4]        53
# (-0.088, 8.7]      38
# Name: DemAge, dtype: int64

# %%
sns.distplot(x)

# %%
df['DemGender'] = df['DemGender'].astype('category')

# %%
df['DemAge'] = df['DemAge'].fillna(value=df['DemAge'].mean())
df['DemAge'] = df['DemAge'].astype(int)

# %%
df['GiftAvgCard36'] = df['GiftAvgCard36'].fillna(value=df['GiftAvgCard36'].mean())

# %%
df = df.drop('TargetD', axis=1)
df.head(10)
# Out:
#    TargetB      ID  GiftCnt36  GiftCntAll  GiftCntCard36  GiftCntCardAll  \
# 0        0   14974          2           4              1               3
# 1        0    6294          1           8              0               3
# 2        1   46110          6          41              3              20
# 3        1  185937          3          12              3               8
# 4        0   29637          1           1              1               1
# 5        1  112632          3          11              2               9
# 6        0  123712          2           4              2               3
# 7        0   45409          1           4              0               3
# 8        1   19094          1           3              0               1
# 9        0  178271          1           5              1               2
#
#    GiftAvgLast  GiftAvg36  GiftAvgAll  GiftAvgCard36  ...  PromCntCardAll  \
# 0         17.0      13.50        9.25          17.00  ...              13
# ...
